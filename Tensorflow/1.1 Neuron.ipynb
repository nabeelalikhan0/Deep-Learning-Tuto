# %% [markdown]
# ---
#
# # 🧠 **What is a Neuron?**
#
# ---
#
# ## 📘 **1. Simple Definition**
#
# * A **neuron** is a tiny part of a big brain.
# * Just like we have brain cells that help us **think**, **feel**, and **learn**, in deep learning, a **neuron** is a tiny computer part that helps the model **learn things**.
#
# ---
#
# ## 🧱 **2. How to Imagine a Neuron**
#
# Imagine a **magical box**:
#
# * It takes something in (like numbers 🍎),
# * It **does a little math magic** ✨,
# * Then it gives something out (another number 🎈).
#
# ---
#
# ## 🔁 **3. What Goes In and What Comes Out?**
#
# ### 🟢 Input:
#
# * Neuron takes **numbers** as input. These numbers could be:
#
#   * A pixel in an image 🖼️,
#   * A word turned into a number 📝,
#   * Temperature or speed 🌡️🚗.
#
# ### ⚙️ Math Magic Inside:
#
# * The neuron multiplies each input by a **weight** (just a number that decides how important that input is).
# * Then it adds everything together.
# * Then it adds a small number called **bias** (just for adjustment).
# * Then it passes the result into a **special function** (called activation function — don’t worry, we’ll learn it later).
#
# ### 🔴 Output:
#
# * The final number that comes out of the neuron is the **output**.
# * This number is used to help decide things like:
#
#   * “Is this a cat?” 🐱
#   * “Should I turn left?” 🛣️
#
# ---
#
# ## 🧠 **4. Real Neuron vs. Artificial Neuron**
#
# | Real Brain Neuron 🧠    | Artificial Neuron 💻 |
# | ----------------------- | -------------------- |
# | Takes signals           | Takes numbers        |
# | Has connections         | Has weights          |
# | Sends signal out        | Sends number out     |
# | Learns by changing      | Learns by changing   |
# | strength of connections | weights              |
#
# ---
#
# ## 🎨 **5. Visual Summary (Imagination)**
#
# ```
#         [Input 1] --\
#                     \
#         [Input 2] -----> [ Neuron ] ---> [ Output ]
#                     /
#         [Input 3] --/
#
# Inside Neuron:
# - Multiply + Add → Use Magic Function → Send result out
# ```
#
# ---
#
# ## 📝 **6. Formula (Don’t Worry, Just a Peek!)**
#
# If the inputs are `x1`, `x2`, `x3`, and weights are `w1`, `w2`, `w3`, and bias is `b`:
#
# ```
# Output = ActivationFunction(x1*w1 + x2*w2 + x3*w3 + b)
# ```
#
# You don't have to memorize it now. Just know it's the **recipe the neuron follows**.
#
# ---
#
# ## 🧩 **7. Why is it Important?**
#
# * A neuron is the **smallest building block** of a deep learning brain (also called a neural network).
# * Just like many Lego blocks make a house 🧱🏠, many neurons make a brain that can:
#
#   * See images,
#   * Understand language,
#   * Play games,
#   * Drive cars,
#   * And more!
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
# # This is an example of a neuron

# %% [markdown]
# ![image.png](attachment:image.png)
# # Mathamatical
#
# ![image-2.png](attachment:image-2.png)

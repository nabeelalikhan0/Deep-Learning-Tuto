# %% [markdown]
# # Derivatives
# ![image-2.png](attachment:image-2.png)
#
# ## For Linear

# %% [markdown]
# ![image.png](attachment:image.png)
# ## For Non Linear
#
# ![image-2.png](attachment:image-2.png)
#
# For this we have to use derivative functions
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Partial Derivatives
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
